# %%
import os

# %%
def list_python_files(directory):
    try:
        files = [f for f in os.listdir(directory) if f.endswith('.py')]
        return files
    except FileNotFoundError:
        return f"The directory {directory} does not exist."

print("here")
directory = '/home/luismiguel/bitbucket/diffractio/diffractio/'
python_files = list_python_files(directory)
print("Python files in the directory:")
for file in python_files:
    print(file)
# Out:
# here
# Python files in the directory:
# vector_sources_XY.py
# scalar_masks_XY.py
# scalar_fields_XYZ.py
# utils_common.py
# scalar_fields_Z.py
# vector_fields_Z.py
# scalar_sources_X.py
# scalar_sources_XY.py
# vector_fields_X.py
# utils_drawing3D.py
# __init__.py
# utils_typing.py
# scalar_fields_X.py
# config.py
# utils_multiprocessing.py
# scalar_masks_XYZ.py
# utils_optics.py
# vector_fields_XY.py
# utils_dxf.py
# vector_fields_XZ.py
# utils_tests.py
# utils_math.py
# scalar_fields_XY.py
# scalar_fields_XZ.py
# vector_fields_XYZ.py
# scalar_masks_XZ.py
# vector_masks_XY.py
# scalar_masks_X.py
# utils_drawing.py

# %%
 
 
def list_classes_and_functions(file_path):
    """
    list_classes_and_functions _summary_

    _extended_summary_

    Args:
        file_path (_type_): _description_

    Returns:
        _type_: _description_
    """
    
    classes = []
    functions = []
    
    with open(file_path, 'r') as file:
        file_content = file.read()

    # Extract classes and functions without using exec
    for line in file_content.splitlines():
        if line.strip().startswith('class '):
            class_name = line.split()[1].split('(')[0]
            classes.append(class_name)
        elif line.strip().startswith('def '):
            function_name = line.split()[1].split('(')[0]
            functions.append(function_name)
    
    # Initialize class_functions after extracting class names
    class_functions = {class_name: [] for class_name in classes}
    standalone_functions = []

    current_class = None
    for line in file_content.splitlines():
        if line.strip().startswith('class '):
            current_class = line.split()[1].split('(')[0]
        elif line.strip().startswith('def '):
            function_name = line.split()[1].split('(')[0]
            if current_class:
                class_functions[current_class].append(function_name)
            else:
                standalone_functions.append(function_name)

    return classes, standalone_functions, class_functions

# %%
directory = '/home/luismiguel/bitbucket/diffractio/diffractio/'
file = 'scalar_masks_XY.py'

file_path = os.path.join(directory, file)
classes, standalone_functions, class_functions = list_classes_and_functions(file_path)

# %%
for class_name in classes:
    print(f"Class: {class_name}")
for function_name in standalone_functions:
    print(f"Standalone Function: {function_name}")
for class_name, functions in class_functions.items():
    print(f"Class {class_name} Functions: {functions}")
# Out:
# Class: Scalar_mask_XY
# Class Scalar_mask_XY Functions: ['__init__', 'set_amplitude', 'set_phase', 'area', 'inverse_amplitude', 'inverse_phase', 'filter', 'widen', 'extrude_mask_x', 'mask_from_function', 'image', 'dxf', 'repeat_structure', 'masks_to_positions', 'polygon', 'regular_polygon', 'star', 'triangle', 'photon_sieve', 'insert_array_masks', 'dots', 'dots_regular', 'one_level', 'two_levels', 'edge_series', 'edge_rough', 'slit', 'slit_rough', 'slit_series', 'double_slit', 'double_slit_rough', 'square', 'gray_scale', 'circle', 'circular_sector', 'super_gauss', 'square_circle', 'angular_aperture', 'ring', 'rings', 'cross', 'prism', 'lens', 'lens_spherical', 'aspheric', 'lens_cylindrical', 'fresnel_lens', 'axicon', 'axicon_binary', 'biprism_fresnel', 'radial_grating', 'angular_grating', 'hyperbolic_grating', 'hammer', 'archimedes_spiral', 'laguerre_gauss_spiral', 'forked_grating', 'sine_grating', 'sine_edge_grating', 'ronchi_grating', 'binary_grating', 'blazed_grating', 'grating_2D', 'grating_2D_chess', 'roughness', 'circle_rough', 'ring_rough', 'fresnel_lens_rough', 'super_ellipse', 'superformula', 'elliptical_phase', 'sinusoidal_slit', 'crossed_slits', 'hermite_gauss_binary', 'laguerre_gauss_binary']

# %%
def print_data_from_file(file_path) -> None:
    classes, standalone_functions, class_functions = list_classes_and_functions(file_path)
    print("Classes:")
    for cl in classes:
        print(cl)
        for function in class_functions[cl]:
            print("     {}".format(function))
    print("Standalone functions:")
    for function in standalone_functions:
        print(function)

# %%
print_data_from_file(file_path)
# Out:
# Classes:
# Scalar_mask_XY
#      __init__
#      set_amplitude
#      set_phase
#      area
#      inverse_amplitude
#      inverse_phase
#      filter
#      widen
#      extrude_mask_x
#      mask_from_function
#      image
#      dxf
#      repeat_structure
#      masks_to_positions
#      polygon
#      regular_polygon
#      star
#      triangle
#      photon_sieve
#      insert_array_masks
#      dots
#      dots_regular
#      one_level
#      two_levels
#      edge_series
#      edge_rough
#      slit
#      slit_rough
#      slit_series
#      double_slit
#      double_slit_rough
#      square
#      gray_scale
#      circle
#      circular_sector
#      super_gauss
#      square_circle
#      angular_aperture
#      ring
#      rings
#      cross
#      prism
#      lens
#      lens_spherical
#      aspheric
#      lens_cylindrical
#      fresnel_lens
#      axicon
#      axicon_binary
#      biprism_fresnel
#      radial_grating
#      angular_grating
#      hyperbolic_grating
#      hammer
#      archimedes_spiral
#      laguerre_gauss_spiral
#      forked_grating
#      sine_grating
#      sine_edge_grating
#      ronchi_grating
#      binary_grating
#      blazed_grating
#      grating_2D
#      grating_2D_chess
#      roughness
#      circle_rough
#      ring_rough
#      fresnel_lens_rough
#      super_ellipse
#      superformula
#      elliptical_phase
#      sinusoidal_slit
#      crossed_slits
#      hermite_gauss_binary
#      laguerre_gauss_binary
# Standalone functions:

# %%
print("Python files in the directory:")
for file in python_files:
    print(file)
    file_path = os.path.join(directory, file)
    classes, standalone_functions, class_functions = list_classes_and_functions(file_path)
    print_data_from_file(file_path)
    print("\n\n")
# Out:
# Python files in the directory:
# vector_sources_XY.py
# Classes:
# Vector_source_XY
#      __init__
#      constant_polarization
#      azimuthal_wave
#      radial_wave
#      radial_inverse_wave
#      azimuthal_inverse_wave
#      local_polarized_vector_wave
#      local_polarized_vector_wave_radial
#      local_polarized_vector_wave_hybrid
#      spiral_polarized_beam
#      to_py_pol
#      define_initial_field
# Standalone functions:
#
#
#
# scalar_masks_XY.py
# Classes:
# Scalar_mask_XY
#      __init__
#      set_amplitude
#      set_phase
#      area
#      inverse_amplitude
#      inverse_phase
#      filter
#      widen
#      extrude_mask_x
#      mask_from_function
#      image
#      dxf
#      repeat_structure
#      masks_to_positions
#      polygon
#      regular_polygon
#      star
#      triangle
#      photon_sieve
#      insert_array_masks
#      dots
#      dots_regular
#      one_level
#      two_levels
#      edge_series
#      edge_rough
#      slit
#      slit_rough
#      slit_series
#      double_slit
#      double_slit_rough
#      square
#      gray_scale
#      circle
#      circular_sector
#      super_gauss
#      square_circle
#      angular_aperture
#      ring
#      rings
#      cross
#      prism
#      lens
#      lens_spherical
#      aspheric
#      lens_cylindrical
#      fresnel_lens
#      axicon
#      axicon_binary
#      biprism_fresnel
#      radial_grating
#      angular_grating
#      hyperbolic_grating
#      hammer
#      archimedes_spiral
#      laguerre_gauss_spiral
#      forked_grating
#      sine_grating
#      sine_edge_grating
#      ronchi_grating
#      binary_grating
#      blazed_grating
#      grating_2D
#      grating_2D_chess
#      roughness
#      circle_rough
#      ring_rough
#      fresnel_lens_rough
#      super_ellipse
#      superformula
#      elliptical_phase
#      sinusoidal_slit
#      crossed_slits
#      hermite_gauss_binary
#      laguerre_gauss_binary
# Standalone functions:
#
#
#
# scalar_fields_XYZ.py
# Classes:
# Scalar_field_XYZ
#      __init__
#      xy_2_xyz
#      __str__
#      __add__
#      __sub__
#      __rotate__
#      __rotate_axis__
#      conjugate
#      normalize
#      duplicate
#      reduce_to_1
#      clear_field
#      clear_refractive_index
#      save_data
#      load_data
#      intensity
#      cut_resample
#      incident_field
#      final_field
#      __RS_multiprocessing__
#      RS
#      RS_amplification
#      BPM
#      PWD
#      WPM
#      to_Scalar_field_XY
#      to_Scalar_field_XZ
#
#
# Standalone functions:
# to_Scalar_field_YZ
# to_Scalar_field_Z
# average_intensity
# beam_widths
# surface_detection
# draw_proposal
# draw_XY
# draw_XZ
# draw_YZ
# draw_XYZ
# video_isovalue
# video
# f
#
#
#
# utils_common.py
# Classes:
# Standalone functions:
# computer_parameters
# clear_all
# several_propagations
# get_date
# save_data_common
# load_data_common
# print_data_dict
# print_axis_info
# date_in_name
#
#
#
# scalar_fields_Z.py
# Classes:
# Scalar_field_Z
#      __init__
#      __str__
#      __add__
#      __sub__
#      duplicate
#      conjugate
#      clear_field
#      save_data
#      load_data
#      cut_resample
#      normalize
#      intensity
#      average_intensity
#      FWHM1D
#      DOF
#      draw
# Standalone functions:
#
#
#
# vector_fields_Z.py
# Classes:
# Vector_field_Z
#      __init__
#      __str__
#      __add__
#      save_data
#      load_data
#      clear_field
#      duplicate
#      get
#      apply_mask
#      intensity
#      polarization_states
#      polarization_ellipse
#      normalize
#      draw
#      __draw_intensity__
#      __draw_intensities__
#      __draw_phases__
#      __draw_fields__
#      __draw_stokes__
#      __draw_param_ellipse__
#      __draw1__
# Standalone functions:
#
#
#
# scalar_sources_X.py
# Classes:
# Scalar_source_X
#      __init__
#      plane_wave
#      gauss_beam
#      spherical_wave
#      plane_waves_dict
#      plane_waves_several_inclined
#      gauss_beams_several_parallel
#      gauss_beams_several_inclined
# Standalone functions:
#
#
#
# scalar_sources_XY.py
# Classes:
# Scalar_source_XY
#      __init__
#      plane_wave
#      gauss_beam
#      spherical_wave
#      vortex_beam
#      hermite_gauss_beam
#      laguerre_beam
#      zernike_beam
#      bessel_beam
#      plane_waves_dict
#      plane_waves_several_inclined
#      gauss_beams_several_parallel
#      gauss_beams_several_inclined
# Standalone functions:
#
#
#
# vector_fields_X.py
# Classes:
# Vector_field_X
#      __init__
#      __str__
#      __add__
#      save_data
#      load_data
#      clear_field
#      duplicate
#      get
#      apply_mask
#      intensity
#      polarization_states
#      polarization_ellipse
#      normalize
#      draw
#      __draw_intensity__
#      __draw_intensities__
#      __draw_phases__
#      __draw_fields__
#      __draw_stokes__
#      __draw_param_ellipse__
#      __draw1__
# Standalone functions:
#
#
#
# utils_drawing3D.py
# Classes:
# Standalone functions:
# load_stl
# voxelize_volume_diffractio
# voxelize_volume_diffractio_backup
# draw
# video_isovalue
# show_stl
#
#
#
# __init__.py
# Classes:
# Standalone functions:
#
#
#
# utils_typing.py
# Classes:
# Standalone functions:
# make_new_user
# stop
#
#
#
# scalar_fields_X.py
# Classes:
# Scalar_field_X
#      __init__
#      __str__
#      __add__
#      __sub__
#      __mul__
#      conjugate
#      duplicate
#      reduce_to_1
#      clear_field
#      save_data
#      load_data
#      cut_resample
#      incident_field
#      inverse_amplitude
#      inverse_phase
#      filter
#      insert_mask
#      pupil
#      insert_array_masks
#      repeat_structure
#      fft
#      ifft
#      _RS_
#      RS
#      CZT
#      WPM
#      normalize
#      MTF
#      intensity
#      average_intensity
#      get_edges
#      get_RS_minimum_z
#      draw
#      kernelRS
#      kernelRSinverse
#      PWD_kernel
#      WPM_schmidt_kernel
#      polychromatic_multiprocessing
#      extended_source_multiprocessing
#      extended_polychromatic_source
#      quality_factor
#      get_RS_minimum_z
# Standalone functions:
#
#
#
# config.py
# Classes:
# Standalone functions:
#
#
#
# utils_multiprocessing.py
# Classes:
# auxiliar_multiprocessing
#      __init__
#      execute_multiprocessing
#      method_single_proc
#      execute_multiprocessing
#      __function_process__
#      creation_dictionary_multiprocessing
# Standalone functions:
# _pickle_method
# _unpickle_method
# separate_from_iterable
#
#
#
# scalar_masks_XYZ.py
# Classes:
# Scalar_mask_XYZ
#      __init__
#      object_by_surfaces
#      sphere
#      square
#      cylinder
#      stl
# Standalone functions:
#
#
#
# utils_optics.py
# Classes:
# Standalone functions:
# roughness_1D
# roughness_2D
# beam_width_1D
# width_percentage
# beam_width_2D
# refractive_index
# FWHM1D
# FWHM2D
# DOF
# detect_intensity_range
# MTF_ideal
# lines_mm_2_cycles_degree
# MTF_parameters
# gauss_spectrum
# lorentz_spectrum
# uniform_spectrum
# normalize_field
# field_parameters
# convert_phase2heigths
# convert_amplitude2heigths
# fresnel_equations_kx
# transmitances_reflectances_kx
# fresnel_equations
# transmitances_reflectances
#
#
#
# vector_fields_XY.py
# Classes:
# Vector_field_XY
#      __init__
#      __str__
#      __add__
#      __rotate__
#      save_data
#      load_data
#      clear
#      duplicate
#      get
#      pupil
#      apply_mask
#      intensity
#      RS
#      VFFT
#      IVFFT
#      VRS
#      CZT
#      polarization_states
#      polarization_ellipse
#      normalize
#      cut_resample
#      draw
#      __draw_intensity__
#      __draw_phases__
#      __draw_intensities__
#      __draw_intensities_rz__
#      __draw_fields__
#      __draw_stokes__
#      __draw_param_ellipse__
#      __draw_ellipses__
#      __draw1__
#      _compute1Elipse__
# Standalone functions:
#
#
#
# utils_dxf.py
# Classes:
# Standalone functions:
# set_pixel_density
# set_pixel_size
# binarize
# load_dxf
#
#
#
# vector_fields_XZ.py
# Classes:
# Vector_field_XZ
#      __init__
#      __str__
#      __add__
#      save_data
#      load_data
#      clear_field
#      duplicate
#      incident_field
#      final_field
#      refractive_index_from_scalarXZ
#      get
#      apply_mask
#      FP_WPM
#      intensity
#      Poynting_vector
#      Poynting_vector_averaged
#      Poynting_total
#      energy_density
#      irradiance
#      check_energy
#      polarization_states
#      polarization_ellipse
#      normalize
#      draw
#      __draw_intensity__
#      __draw_intensities__
#      __draw_phases__
#      __draw_fields__
#      __draw_EH__
#      __draw_stokes__
#      __draw_param_ellipse__
#      __draw_ellipses__
#      __draw1__
#      polarization_ellipse
#      FP_PWD_kernel_simple
#      FP_WPM_schmidt_kernel
#      draw_field
#      draw2D_proposal
#      format_drawing
# Standalone functions:
#
#
#
# utils_tests.py
# Classes:
# Standalone functions:
# _test_slit_RS_XY
# run_benchmark
# test_pixels
# comparison
# save_figure_test
# ejecute_multiprocessing
# benchmark_num_pixels
# benchmark_processors_n_pixels
# save_data_test
#
#
#
# utils_math.py
# Classes:
#
# Standalone functions:
# nextpow2
# Bluestein_dft_x
# Bluestein_dft_xy
# find_local_extrema
# reduce_to_1
# distance
# nearest
# nearest2
# find_extrema
# get_amplitude
# get_phase
# amplitude2phase
# phase2amplitude
# normalize
# binarize
# discretize
# delta_kronecker
# vector_product
# dot_product
# divergence
# curl
# get_edges
# cut_function
# fft_convolution2d
# fft_convolution1d
# fft_filter
# fft_correlation1d
# fft_correlation2d
# rotate_image
# cart2pol
# pol2cart
# fZernike
# laguerre_polynomial_nk
# get_k
# filter_edge_1D
# filter_edge_2D
#
#
#
# scalar_fields_XY.py
# Classes:
# Scalar_field_XY
#      __init__
#      __str__
#      __add__
#      __sub__
#      __mul__
#      __rotate__
#      conjugate
#      duplicate
#      reduce_to_1
#      add
#      rotate
#      apodization
#      clear_field
#      save_data
#      load_data
#      save_mask
#      cut_resample
#      incident_field
#      pupil
#      fft_proposal
#      fft
#      ifft_proposal
#      ifft
#      _RS_
#      RS
#      WPM
#      CZT
#      profile
#      draw_profile
#      get_edges
#      search_focus
#      MTF
#      beam_width_4s
#      intensity
#      average_intensity
#      send_image_screen
#      get_amplitude
#      get_phase
#      remove_phase
#      binarize
#      discretize
#      normalize
#      get_RS_minimum_z
#      draw
#      __draw_intensity__
#      __drawAmplitude__
#      __draw_phase__
#      __draw_field__
#      __draw_real_field__
#      video
#      animate
#      kernelRS
#      kernelRSinverse
#      kernelFresnel
#      PWD_kernel
#      WPM_schmidt_kernel
#      get_RS_minimum_z
#      quality_factor
# Standalone functions:
#
#
#
# scalar_fields_XZ.py
# Classes:
# Scalar_field_XZ
#      __init__
#      __str__
#      __add__
#      __sub__
#      __rotate__
#      reduce_to_1
#      duplicate
#      refractive_index_from_scalar_mask_XY
#      rotate_field
#      clear_field
#      clear_refractive_index
#      normalize
#      mask_field
#      smooth_refractive_index
#      save_data
#      load_data
#      cut_resample
#      incident_field
#      final_field
#      __BPM__
#      BPM
#      BPM_inverse
#      BPM_back_propagation
#      __RS_multiprocessing__
#      RS
#      PWD
#      WPM
#      RS_polychromatic
#      BPM_polychromatic
#      WPM_polychromatic
#      fast_propagation
#      intensity
#      average_intensity
#      check_intensity
#      detect_index_variations
#      _detect_transitions_
#      surface_detection
#      draw
#      draw_refractive_index
#      draw_incident_field
#      profile_longitudinal
#      profile_transversal
#      search_focus
#      beam_widths
#      video
#      init
#      animate
#      draw_profiles_interactive
#      __update__
# Standalone functions:
#
#
#
# vector_fields_XYZ.py
# Classes:
# Vector_field_XYZ
#      __init__
#      __str__
#      __add__
#      save_data
#      load_data
#      clear_field
#      duplicate
#      get
#      intensity
#      polarization_states
#      polarization_ellipse
#      normalize
#      to_Vector_field_XY
#
#
#
# Standalone functions:
# to_Vector_field_XZ
# to_Vector_field_YZ
# to_Vector_field_Z
# draw_XY
# draw_XZ
# draw_YZ
# _compute1Elipse__
#
#
#
# scalar_masks_XZ.py
# Classes:
# Scalar_mask_XZ
#      __init__
#      extrude_mask
#      mask_from_function
#      mask_from_array
#      mask_from_array_proposal
#      object_by_surfaces
#      add_surfaces
#      discretize_refractive_index
#      _discretize_
#      image
#      dxf
#      dots
#      semi_plane
#      layer
#      rectangle
#      slit
#      cylinder
#      semi_sphere
#      lens_plane_convergent
#      lens_convergent
#      lens_plane_divergent
#      lens_divergent
#      aspheric_surface_z
#      aspheric_lens
#      wedge
#      prism
#      biprism
#      ronchi_grating
#      sine_grating
#      probe
#      rough_sheet
# Standalone functions:
#
#
#
# vector_masks_XY.py
# Classes:
# Vector_mask_XY
#      __init__
#      __add__
#      __mul__
#      __rmul__
#      duplicate
#      apply_circle
#      pupil
#      scalar_to_vector_mask
#      complementary_masks
#      multilevel_mask
#      from_py_pol
#      polarizer_linear
#      quarter_waveplate
#      half_waveplate
#      polarizer_retarder
#      to_py_pol
#      draw
#      rotation_matrix_Jones
# Standalone functions:
#
#
#
# scalar_masks_X.py
# Classes:
# Scalar_mask_X
#      __init__
#      filter
#      mask_from_function
#      mask_from_array
#      dots
#      slit
#      double_slit
#      two_levels
#      gray_scale
#      prism
#      biprism_fresnel
#      biprism_fresnel_nh
#      lens
#      lens_spherical
#      aspheric
#      fresnel_lens
#      roughness
#      dust_different_sizes
#      dust
#      sine_grating
#      ronchi_grating
#      binary_grating
#      blazed_grating
#      chirped_grating_p
#      chirped_grating_q
#      chirped_grating
#      binary_code_positions
#      binary_code
# Standalone functions:
#
#
#
# utils_drawing.py
# Classes:
# Standalone functions:
# view_image
# concatenate_drawings
# draw2D
# draw_several_fields
# change_image_size
# extract_image_from_video
# normalize_draw
# prepare_drawing
# prepare_video
# make_video_from_file
# reduce_matrix_size

# %%
 with open('output.txt', 'w') as rst_file:
        rst_file.write("Python files in the directory:\n")
        for file in python_files:
            rst_file.write(f"{file}\n")
            file_path = os.path.join(directory, file)
            classes, standalone_functions, class_functions = list_classes_and_functions(file_path)
            rst_file.write("Classes:\n")
            for cl in classes:
                rst_file.write(f"{cl}\n")
                for function in class_functions[cl]:
                    rst_file.write(f"    {function}\n")
            rst_file.write("Standalone functions:\n")
            for function in standalone_functions:
                rst_file.write(f"{function}\n")
            rst_file.write("\n\n")

# %%
with open('output.txt', 'w') as rst_file:
    rst_file.write("Python files in the directory:\n")
    for file in python_files:
        rst_file.write(f"{file}\n")
        file_path = os.path.join(directory, file)
        classes, standalone_functions, class_functions = list_classes_and_functions(file_path)
        rst_file.write("Classes:\n")
        for cl in classes:
            rst_file.write(f"{cl}\n")
            for function in class_functions[cl]:
                rst_file.write(f"    {function}\n")
        rst_file.write("Standalone functions:\n")
        for function in standalone_functions:
            rst_file.write(f"{function}\n")
        rst_file.write("\n\n")
    rst_file.write(f"Total number of Python files: {len(python_files)}\n")
    for file in python_files:
        file_path = os.path.join(directory, file)
        classes, standalone_functions, class_functions = list_classes_and_functions(file_path)
        rst_file.write(f"\nFile: {file}\n")
        rst_file.write(f"Number of classes: {len(classes)}\n")
        for cl in classes:
            rst_file.write(f"Class: {cl}, Number of functions: {len(class_functions[cl])}\n")

# %%
 
 with open('output.rst', 'w') as rst_file:
    rst_file.write("Python files in the directory:\n")
    rst_file.write("================================\n\n")
    for file in sorted(python_files):
        rst_file.write(f"{file}\n")
        rst_file.write("__________________________________________________\n\n")

        file_path = os.path.join(directory, file)
        classes, standalone_functions, class_functions = list_classes_and_functions(file_path)
        for cl in classes:
            if cl not in ('', [], None):
                rst_file.write(f" Class: **{cl}**\n")
                rst_file.write(f"   Number of functions: {len(class_functions[cl])}\n\n")

            for function in class_functions[cl]:
                rst_file.write(f"    - {function}\n\n")
        rst_file.write("\n Standalone functions:\n\n")
        rst_file.write(f"   Number of functions: {len(standalone_functions)}\n\n")

        for function in standalone_functions:
            rst_file.write(f"  - {function}\n\n")
        rst_file.write("\n\n\n\n")
        
        
    rst_file.write(f"Python files and lines\n")
    rst_file.write(f"============================\n\n")
    rst_file.write(f"Total number of Python files: {len(python_files)}\n\n")
    
    
    ## Number of lines in each file

    for file in python_files:
        file_path = os.path.join(directory, file)
        classes, standalone_functions, class_functions = list_classes_and_functions(file_path)
        rst_file.write(f"\nFile: {file}\n")
        rst_file.write(f"_____________________________________________________________________\n\n")

        with open(file_path, 'r') as f:
            lines = f.readlines()
            num_lines = len(lines)
            rst_file.write(f"  Number of lines: {num_lines}\n\n")
        rst_file.write(f"  Number of classes: {len(classes)}\n\n")
        for cl in classes:
            rst_file.write(f"    Class: {cl}, Number of functions: {len(class_functions[cl])}\n\n")
            

    total_lines = sum(len(open(os.path.join(directory, file), 'r').readlines()) for file in python_files)
    
    
    rst_file.write(f"Total\n")
    rst_file.write(f"============================\n\n")
    rst_file.write(f"\nTotal number of lines across all files: {total_lines}\n\n")
