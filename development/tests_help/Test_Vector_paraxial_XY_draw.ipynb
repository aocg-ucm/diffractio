# %% [markdown]
# # Test_Vector_paraxial_XY_draw

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'png'
from pprint import pprint

# %%
from matplotlib import rcParams

# %%
rcParams['figure.figsize']=5,5
rcParams['font.size']=14
rcParams['figure.dpi']=200

# %%
from diffractio import degrees, mm, nm, np, plt, sp, um
from diffractio.scalar_fields_XY import Scalar_field_XY
from diffractio.scalar_masks_XY import Scalar_mask_XY
from diffractio.scalar_sources_XY import Scalar_source_XY

from diffractio.vector_paraxial_masks_XY import Vector_paraxial_mask_XY
from diffractio.vector_paraxial_sources_XY import Vector_paraxial_source_XY

from diffractio.utils_drawing import concatenate_drawings, draw_several_fields
# Out:
# number of processors: 8

# %%
v_lineal = (1, 0)
v_circular = (1, 1j) / np.sqrt(2)

# %%
length = 500 * um
num_data = 256
wavelength = 0.6328 * um

x0 = np.linspace(-length / 2, length / 2, num_data)
y0 = np.linspace(-length / 2, length / 2, num_data)

EM = Vector_paraxial_source_XY(x0, y0, wavelength)
EM.radial_wave(A=1, x_center=(0 * um, 0 * um), radius=length / 5)
EM.RS(z=10*mm, new_field=False)

Ex,Ey=EM.get()

EM.reduce_matrix=''

# %% [markdown]
# ## Draw intensity

# %%
#EM.__draw_intensity__();
EM.draw(kind='intensity');

# %%
#EM.__draw_intensities__();
EM.draw(kind='intensities');

# %% [markdown]
# ## Draw phase

# %%
#EM.__draw_phases__();
EM.draw(kind='phases');
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fe43192fa20>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fe433654f98>)

# %% [markdown]
# ## draw field

# %%
#EM.__draw_field__();
EM.draw(kind='fields');
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fe433ae61d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fe433bd18d0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fe433c24e48>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fe431956400>)

# %% [markdown]
# ## Draw Stokes (incluir poder sacar de 1 en 1)

# %%
EM.draw(kind='stokes');

# %%
#EM.__draw_param_ellipse__();
EM.draw(kind='param_ellipse');

# %% [markdown]
# ## def test_polarization_ellipse(self):

# %%
EM.__draw_ellipses__(
    num_ellipses=(30, 30),
    amplification=0.5,
    max_size=100,
    color_line='r',
    line_width=.5,
    draw_arrow=True,
    head_width=2,
    ax=False,
    percentaje_intensity=0.05)

# %%
h1,h2=EM.draw(kind='intensities')
EM.__draw_ellipses__(
    num_ellipses=(30, 30),
    amplification=0.5,
    max_size=100,
    color_line='w',
    line_width=.5,
    draw_arrow=True,
    head_width=2,
    ax=h1,
    percentaje_intensity=0.02)

EM.__draw_ellipses__(
    num_ellipses=(30, 30),
    amplification=0.5,
    max_size=100,
    color_line='y',
    line_width=.5,
    draw_arrow=True,
    head_width=2,
    ax=h2,
    percentaje_intensity=0.02)
