# %% [markdown]
# # Test_vector_paraxial_sources_XY

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext line_profiler
# %matplotlib inline
# %config InlineBackend.figure_format = 'png'
from pprint import pprint

# %%
from matplotlib import rcParams
rcParams['figure.figsize']=5,5
rcParams['font.size']=14

# %%
from diffractio import degrees, mm, np, um
from diffractio.scalar_masks_XY import Scalar_mask_XY
from diffractio.scalar_sources_XY import Scalar_source_XY
from diffractio.vector_paraxial_masks_XY import Vector_paraxial_mask_XY
from diffractio.vector_paraxial_sources_XY import Vector_paraxial_source_XY

# %%
polarization_x = [1, 0]
polarization_y = [0, 1]
polarization_right = [1, 1.j] / np.sqrt(2)
polarization_left = [1, -1.j] / np.sqrt(2)
polarization_45 = [1, 1] / np.sqrt(2)
polarization_m45 = [1, -1] / np.sqrt(2)

# %% [markdown]
# ## def test_wave_from_scalar(self):

# %%
length = 25 * um
num_data = 1024
x0 = np.linspace(-length / 2, length / 2, num_data)
y0 = np.linspace(-length / 2, length / 2, num_data)
wavelength = 1 * um

u1 = Scalar_source_XY(x=x0, y=y0, wavelength=wavelength)
u1.gauss_beam(
    A=1,
    r0=(0 * um, 0 * um),
    w0=(6 * um, 6 * um),
    z0=0 * um,
    theta=0. * degrees,
    phi=0 * degrees)

EM = Vector_paraxial_mask_XY(x0, y0, wavelength)
EM.unique_mask(u1, v=polarization_right)
EM.draw(kind='fields');

# %%
EM.draw(kind='stokes');

# %% [markdown]
# ## def test_plane_wave(self):

# %%
length = 500 * um
num_data = 512
x0 = np.linspace(-length / 2, length / 2, num_data)
y0 = np.linspace(-length / 2, length / 2, num_data)
wavelength = 0.6328

# con esto definimos el field E
EM = Vector_paraxial_source_XY(x0, y0, wavelength)
EM.plane_wave(
    A=1 ,
    v=polarization_45,
    theta=1 * degrees,
    phi=45 * degrees)
EM.draw(kind='fields');

# %%
EM.draw(kind='stokes');

# %% [markdown]
# ## def test_interferences(self):

# %%
length = 100 * um
num_data = 512
x0 = np.linspace(-length / 2, length / 2, num_data)
y0 = np.linspace(-length / 2, length / 2, num_data)
wavelength = 0.6328

EM1 = Vector_paraxial_source_XY(x0, y0, wavelength)
EM1.plane_wave(A=1, v=[1, 0], theta=-1 * degrees, phi=0 * degrees)

EM2 = Vector_paraxial_source_XY(x0, y0, wavelength)
EM2.plane_wave(A=1, v=[1, 0], theta=1 * degrees, phi=0 * degrees)

EM = EM1 + EM2
EM.draw(kind='fields');

# %%
EM.draw(kind='stokes');

# %% [markdown]
# ## def test_spherical_wave(self):

# %%
length = 50 * um
num_data = 256
x0 = np.linspace(-length / 2, length / 2, num_data)
y0 = np.linspace(-length / 2, length / 2, num_data)
wavelength = 2

u1 = Scalar_source_XY(x=x0, y=y0, wavelength=wavelength)
u1.spherical_wave(
    A=1 , z0=-5 * mm, radius=length / 2, mask=False)

EM = Vector_paraxial_mask_XY(x0, y0, wavelength)
EM.unique_mask(u1, v=polarization_x)
EM.normalize()
EM.draw(kind='fields');

# %%
EM.draw(kind='stokes');

# %% [markdown]
# ## def test_radial_wave(self):

# %%
length = 250 * um
num_data = 512
x0 = np.linspace(-length / 2, length / 2, num_data)
y0 = np.linspace(-length / 2, length / 2, num_data)
wavelength = 2 * um

EM = Vector_paraxial_source_XY(x0, y0, wavelength)
EM.radial_wave(A=1, x_center=(0 * um, 0 * um), radius=length)

EM.draw(kind='fields');

# %%
EM.draw(kind='stokes');

# %% [markdown]
# ## def test_transversal_wave(self):

# %%
length = 250 * um
num_data = 512
x0 = np.linspace(-length / 2, length / 2, num_data)
y0 = np.linspace(-length / 2, length / 2, num_data)
wavelength = 0.6328

EM = Vector_paraxial_source_XY(x0, y0, wavelength)
EM.transversal_wave(A=1, x_center=(0 * um, 0 * um), radius=length)

EM.draw(kind='fields')
# Out:
# (<matplotlib.image.AxesImage at 0x7f3867ac6748>,
#  <matplotlib.image.AxesImage at 0x7f3867ad3358>)

# %%
EM.draw(kind='stokes');

# %% [markdown]
# ## def test_gaussX(self):

# %%
length = 75 * um
num_data = 512
x0 = np.linspace(-length / 2, length / 2, num_data)
y0 = np.linspace(-length / 2, length / 2, num_data)
wavelength = 2 * um

EM = Vector_paraxial_source_XY(x0, y0, wavelength)
EM.gauss(
    A=1,
    r0=(0 * um, 0 * um),
    w0=(15 * um, 15 * um),
    theta=0. * degrees,
    phi=0 * degrees,
    kind='polarization',
    v=[1, 0])

EM.draw(kind='fields');

# %%
EM.draw(kind='stokes');

# %% [markdown]
# ## def test_gaussRadial(self):

# %%
length = 200 * um
num_data = 512
x0 = np.linspace(-length / 2, length / 2, num_data)
y0 = np.linspace(-length / 2, length / 2, num_data)
wavelength = 2

EM = Vector_paraxial_source_XY(x0, y0, wavelength)
EM.gauss(
    A=1,
    r0=(0 * um, 0 * um),
    w0=(50 * um, 50 * um),
    theta=0. * degrees,
    phi=0 * degrees,
    kind='radial')

EM.draw(kind='fields');

# %%
EM.draw(kind='stokes');

# %% [markdown]
# ## def test_gaussTransversal(self):

# %%
length = 200 * um
num_data = 512
x0 = np.linspace(-length / 2, length / 2, num_data)
y0 = np.linspace(-length / 2, length / 2, num_data)
wavelength = 10

EM = Vector_paraxial_source_XY(x0, y0, wavelength)
EM.gauss(
    A=1,
    r0=(0 * um, 0 * um),
    w0=(50 * um, 50 * um),
    theta=0. * degrees,
    phi=0 * degrees,
    kind='transversal')

EM.draw(kind='fields')
# Out:
# (<matplotlib.image.AxesImage at 0x7f3867b33b38>,
#  <matplotlib.image.AxesImage at 0x7f38679a4128>)

# %%
EM.draw(kind='stokes');

# %% [markdown]
# ## def test_hermite_gauss_wave_radial(self):

# %%
length = 100 * um
num_data = 512
x0 = np.linspace(-length / 2, length / 2, num_data)
y0 = np.linspace(-length / 2, length / 2, num_data)
wavelength = 2 * um

EM = Vector_paraxial_source_XY(x0, y0, wavelength)

EM.hermite_gauss_wave(
    A=1,
    r0=(0 * um, 0 * um),
    w=125 * um,
    m=[2],
    n=[2],
    c_mn=[1],
    kind='radial',
    v=[1, 0])

EM.draw(kind='fields');
# Out:
# 3.9999230009788973

# %%
EM.draw(kind='stokes');

# %% [markdown]
# ## def test_hermite_gauss_wave_transversal(self):

# %%
length = 250 * um
num_data = 512
x0 = np.linspace(-length / 2, length / 2, num_data)
y0 = np.linspace(-length / 2, length / 2, num_data)
wavelength = 5

EM = Vector_paraxial_source_XY(x0, y0, wavelength)
# EM.hermite_gauss_wave(A=1, w=75*um, m = [0,1], n = [0,1], c_mn = [1,1], kind='transversal')
EM.hermite_gauss_wave(
    A=1, w=75 * um, m=[1], n=[1], c_mn=[1], kind='transversal')

EM.draw(kind='fields');
# Out:
# 1.4714258257855581

# %%
EM.draw(kind='stokes');

# %% [markdown]
# ## def test_HG_radial_sum(self):

# %%
length = 200 * um
num_data = 512
x0 = np.linspace(-length / 2, length / 2, num_data)
y0 = np.linspace(-length / 2, length / 2, num_data)
wavelength = 0.6328

EM1 = Vector_paraxial_source_XY(x0, y0, wavelength)
EM1.hermite_gauss_wave(
    A=1,
    w=50 * um,
    m=[1],
    n=[0],
    c_mn=[1],
    kind='polarization',
    v=[1, 0])

EM2 = Vector_paraxial_source_XY(x0, y0, wavelength)
EM2.hermite_gauss_wave(
    A=600,
    w=50 * um,
    m=[0],
    n=[1],
    c_mn=[1],
    kind='polarization',
    v=[0, 1])

EM = EM1 + EM2

EM.draw(kind='fields');
# Out:
# 1.4712721695817026
# 0.9999037552255016

# %%
EM.draw(kind='stokes');

# %% [markdown]
# ## def test_HG_azimuthal_sum(self):

# %%
length = 200 * um
num_data = 512
x0 = np.linspace(-length / 2, length / 2, num_data)
y0 = np.linspace(-length / 2, length / 2, num_data)
wavelength = 2

EM1 = Vector_paraxial_source_XY(x0, y0, wavelength)
EM1.hermite_gauss_wave(
    A=1,
    w=50 * um,
    m=[0],
    n=[1],
    c_mn=[1],
    kind='polarization',
    v=[1, 0])

EM2 = Vector_paraxial_source_XY(x0, y0, wavelength)
EM2.hermite_gauss_wave(
    A=600,
    w=50 * um,
    m=[1],
    n=[0],
    c_mn=[1],
    kind='polarization',
    v=[0, 1])

EM = EM1 + EM2

EM.draw(kind='fields')
# Out:
# 0.9999037552255016
# 1.4712721695817026
# (<matplotlib.image.AxesImage at 0x7f3865f04630>,
#  <matplotlib.image.AxesImage at 0x7f386cc10be0>)

# %%
EM.draw(kind='stokes');

# %% [markdown]
# ## def test_LPVB(self):

# %%
length = 500 * um
num_data = 512
x0 = np.linspace(-length / 2, length / 2, num_data)
y0 = np.linspace(-length / 2, length / 2, num_data)
wavelength = 2

EM = Vector_paraxial_source_XY(x0, y0, wavelength)
EM.local_polarized_vector_beam(
    A=1, r0=(0 * um, 0 * um), m=1.5, fi0=0 * np.pi)

EM.draw(kind='fields');

# %%
EM.draw(kind='stokes');

# %% [markdown]
# ## def test_LPVB_radial(self):

# %%
length = 500 * um
num_data = 512
x0 = np.linspace(-length / 2, length / 2, num_data)
y0 = np.linspace(-length / 2, length / 2, num_data)
wavelength = 2

EM = Vector_paraxial_source_XY(x0, y0, wavelength)
EM.local_polarized_vector_beam_radial(
    A=1, r0=(0 * um, 0 * um), n=0.5, fi0=np.pi / 2)

EM.draw(kind='fields');

# %%
EM.draw(kind='stokes');

# %% [markdown]
# ## def test_LPVB_hibrid(self):

# %%
length = 500 * um
num_data = 512
x0 = np.linspace(-length / 2, length / 2, num_data)
y0 = np.linspace(-length / 2, length / 2, num_data)
wavelength = 2

EM = Vector_paraxial_source_XY(x0, y0, wavelength)
EM.local_polarized_vector_beam_hybrid(
    A=1, r0=(0 * um, 0 * um), m=1, n=3, fi0=np.pi / 2)

EM.draw(kind='fields');

# %%
EM.draw(kind='stokes');

# %% [markdown]
# ## def test_Vector_paraxial_dipole(self):

# %%
length = 1000 * um
num_data = 1024
x0 = np.linspace(-length / 2, length / 2, num_data)
y0 = np.linspace(-length / 2, length / 2, num_data)
wavelength = 4

EM1 = Vector_paraxial_source_XY(x0, y0, wavelength)
EM1.Vector_paraxial_dipole(
    A=1e-9, phase=0 * degrees, p0=[1, 0, 0], z=50 * mm)

t = Scalar_mask_XY(x=x0, y=y0, wavelength=wavelength)
t.circle(r0=(0, 0), radius=(length / 2, length / 2), angle=0)

EM2 = Vector_paraxial_mask_XY(x0, y0, wavelength)
EM2.unique_mask(t, v=[1, 1, 1])

EM1 = EM1 * EM2

# %%
t1 = Scalar_mask_XY(x=x0, y=y0, wavelength=wavelength)
focal = 2 * mm
t1.lens(
    r0=(0 * um, 0 * um),
    radius=(length / 50, length / 50),
    focal=(focal, focal),
    angle=0 * degrees,
    mask=True)

EM2 = Vector_paraxial_mask_XY(x0, y0, wavelength)
EM2.unique_mask(t1, v=[1, 1, 1])

EM = EM1 * EM2

EM.normalize()
EM.draw(kind='fields')
# Out:
# (<matplotlib.image.AxesImage at 0x7f386c5db2e8>,
#  <matplotlib.image.AxesImage at 0x7f386cc71898>)

# %%
EM2=EM.cut_resample(x_limits=[-30,30],
    y_limits=[-30,30],
    num_points='',
    new_field=True,
    interp_kind=(3, 1));

# %%
EM2.draw(kind='stokes');
