# %% [markdown]
# # Dummy example

# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,1,10)

plt.figure()
plt.plot(x,x**2,'k')
# Out:
# <img src="data:image/png;base64,..." width="639.85">
