# %% [markdown]
# # Vortex beam

# %%
# configuration
# %load_ext autoreload
# %autoreload 2
# %load_ext line_profiler
# %matplotlib inline
# %config InlineBackend.figure_format = 'png'

from pprint import pprint

# %%
from diffractio import sp, nm, plt, np, mm, degrees, um, params_drawing
from diffractio.scalar_masks_XY import Scalar_mask_XY
from diffractio.scalar_sources_XY import Scalar_source_XY

from diffractio.utils_math import ndgrid

import matplotlib.cm as cm
# Out:
# number of processors: 8

# %%
from matplotlib import rcParams
rcParams['figure.figsize']=(8,8)

# %%
params_drawing['percentaje_intensity']=0

# %% [markdown]
# ## Vortex beam passing through an circular aperture

# %%
x0 = np.linspace(-200*um, 200*um, 1024)
y0 = np.linspace(-200*um, 200*um, 1024)
wavelength = 0.6238 * um



# Generación de la clase
u0 = Scalar_source_XY(x=x0, y=y0, wavelength=wavelength)
# carga de la onda esferica
u0.vortex_beam(r0=(0,0), w0=60*um, m=4)

t0=Scalar_mask_XY(x=x0, y=y0, wavelength=wavelength)
t0.circle(r0=(0,0), radius=(150*um,150*um))

u1=u0*t0

u2=u1.RS(z=15*mm, new_field=True, verbose=True);
u2.normalize()
# Out:
# Good result: factor  56.69602790566206

# %%
u1.draw('field');

# %%
# draw la onda esferica
u2.draw(kind='field');

# %%
# draw la onda esferica
u2.draw(kind='phase', normalize='maximum', has_colorbar='vertical');

# %%
# draw la onda esferica
u2.draw(kind='real_field', has_colorbar='vertical');

# %%
# draw la onda esferica
u2.draw(kind='field');
