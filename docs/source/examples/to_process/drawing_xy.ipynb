# %% [markdown]
# # Drawing XY: focal area of an apheric lens

# %%
# configuration
# %load_ext autoreload
# %autoreload 2
# %load_ext line_profiler
# %matplotlib inline
# %config InlineBackend.figure_format = 'png'

from pprint import pprint

# %%
from diffractio import sp, nm, plt, np, mm, degrees, um
from diffractio.scalar_masks_XY import Scalar_mask_XY
from diffractio.scalar_sources_XY import Scalar_source_XY

from diffractio.utils_math import ndgrid

import matplotlib.cm as cm
# Out:
# number of processors: 8

# %%
from matplotlib import rcParams
rcParams['figure.figsize']=(8,8)

# %% [markdown]
# ## Vortex beam passing through an circular aperture

# %%
x0 = np.linspace(-125*um, 125*um, 1024)
y0 = np.linspace(-125*um, 125*um, 1024)
wavelength = 0.6238 * um



# Generación de la clase
u0 = Scalar_source_XY(x=x0, y=y0, wavelength=wavelength)
# carga de la onda esferica
u0.vortex_beam(r0=(0,0), w0=50*um, m=3)

t0 = Scalar_mask_XY(x=x0, y=y0, wavelength=wavelength)
t0.circle(r0=(0,0), radius=(80*um, 80*um))
u1=u0*t0

u1.RS(z=.5*mm, new_field=False, verbose=True);
u1.normalize()
# Out:
# Good result: factor  5.389649625292991

# %%
u0.draw()
# Out:
# (<Figure size 576x576 with 1 Axes>,
# ...
#  <matplotlib.image.AxesImage at 0x7faeedcfe860>)

# %%
t0.draw();

# %%
# draw la onda esferica
u1.draw(kind='intensity', normalize='maximum', has_colorbar='vertical');

# %%
# draw la onda esferica
u1.draw(kind='amplitude', normalize='maximum', has_colorbar='vertical');

# %%
# draw la onda esferica
u1.draw(kind='phase', normalize='maximum', has_colorbar='vertical');

# %%
# draw la onda esferica
u1.draw(kind='fieldReal', normalize='maximum', has_colorbar='vertical');

# %%
# draw la onda esferica
u1.draw(kind='field', normalize='maximum');
